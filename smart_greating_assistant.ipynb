# %% [markdown]
# <a href="https://colab.research.google.com/github/kinfe19/primeet-Chatbot/blob/main/smart_greating_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to my greating assistant")

name = input("what is your name: ")

time = input('it is morning, afternoon, evening  ').lower()

if time == "good morning":
  greeting = "Good morning Dude"
elif time == "good afternoon":
  greeting = "Good afternoon man"
else:
  greeting = 'Welcome brother'

print(f"{greeting} to kin assistan mr {name} would you learn about computer science")
# Out:
# welcome to my greating assistant
# what is your name: KIN
# it is morning, afternoon, evening  GOOD MORNING
# Good morning Dude to kin assistan mr KIN would you learn about computer science
