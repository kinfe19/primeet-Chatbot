# %% [markdown]
# <a href="https://colab.research.google.com/github/kinfe19/primeet-Chatbot/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def get_weather(city, api_key):
    # URL to fetch weather data from OpenWeatherMap API
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

    try:
        response = requests.get(url)
        data = response.json()

        if response.status_code == 200:
            # Extract data from the response
            city_name = data['name']
            temperature = data['main']['temp']
            weather_description = data['weather'][0]['description']
            weather_icon = data['weather'][0]['icon']
            icon_url = f"http://openweathermap.org/img/wn/{weather_icon}.png"

            # Print the weather details
            print(f"Weather in {city_name}:")
            print(f"Temperature: {temperature}°C")
            print(f"Description: {weather_description}")
            print(f"Icon: {icon_url}")

        else:
            print(f"Error: {data['message']}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching weather data: {e}")

def main():
    # Get the city name from the user
    city = input("Enter the city name: ")

    # Your API key from OpenWeatherMap
    api_key = "YOUR_API_KEY"  # Replace with your actual API key

    get_weather(city, api_key)

if __name__ == "__main__":
    main()
# Out:
# Enter the city name: London
# Error: Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.
